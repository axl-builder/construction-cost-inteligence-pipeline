# %%
import yfinance as yf

# %%
lumber = yf.Ticker("LBR=F")
print(lumber.history(period="5d", interval="1m").shape)
print(lumber.history(period="5d", interval="1m").head())
# Out:
# (224, 7)
#                             Open   High    Low  Close  Volume  Dividends  \
# Datetime
# 2026-04-17 10:00:00-04:00  585.0  588.0  584.5  588.0       0        0.0
# 2026-04-17 10:01:00-04:00  588.0  588.0  588.0  588.0       4        0.0
# 2026-04-17 10:02:00-04:00  588.0  588.0  588.0  588.0       1        0.0
# 2026-04-17 10:03:00-04:00  587.5  587.5  583.0  583.0      18        0.0
# 2026-04-17 10:04:00-04:00  584.5  584.5  583.0  583.0       8        0.0
#
#                            Stock Splits
# Datetime
# 2026-04-17 10:00:00-04:00           0.0
# 2026-04-17 10:01:00-04:00           0.0
# 2026-04-17 10:02:00-04:00           0.0
# 2026-04-17 10:03:00-04:00           0.0
# 2026-04-17 10:04:00-04:00           0.0

# %%
glass1 = yf.Ticker("OC")    # Owens Corning — vidrio y aislamiento
glass2 = yf.Ticker("APOG")  # Apogee Enterprises — vidrio arquitectónico
glass3 = yf.Ticker("TREX")  # Trex — materiales construcción
print("OC:", glass1.history(period="5d", interval="1m").shape)
print("APOG:", glass2.history(period="5d", interval="1m").shape)
# Out:
# OC: (1728, 7)
# APOG: (556, 7)
